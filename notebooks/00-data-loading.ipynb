# %% [markdown]
# # 00: Data Loading & Validation
#
# Load sensor data from source, validate schema, handle missing values, and prepare for analysis.
#
# ## Objectives:
# - Import sensor readings from CSV/database
# - Validate data types and value ranges
# - Handle missing values and sensor failures
# - Perform basic cleaning and preprocessing
# - Output clean dataset for downstream analysis

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# Load sensor data
# df = pd.read_csv('../data/raw/sensor_readings.csv')
# print(f'Loaded {len(df)} records')
# df.head()

# %%
# Data validation
# print(f'Shape: {df.shape}')
# print(f'Columns: {df.columns.tolist()}')
# print(f'Missing values:\n{df.isnull().sum()}')
# print(f'Data types:\n{df.dtypes}')

# %%
# Handle missing values and clean data
# TODO: Implement preprocessing logic
# 1. Handle missing sensor readings
# 2. Validate ranges (soil_moisture 0-100, temp -40 to 80)
# 3. Remove or flag duplicates
# 4. Save clean data
