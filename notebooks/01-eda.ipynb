# %% [markdown]
# # 01: Exploratory Data Analysis
#
# Analyze sensor patterns, distributions, correlations, and temporal trends.
#
# ## Objectives:
# - Statistical summaries per sensor
# - Distribution analysis and visualization
# - Correlation analysis (sensors)
# - Temporal patterns (daily/weekly/seasonal)
# - Anomaly detection
